# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Shafaquat/Project-4-Assignments/blob/main/01_expressions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

def roll_dice():
    die1:int = random.randint(1,6)
    die2:int = random.randint(1,6)
    total:int = die1 + die2
    print(f'Total of two dice: {total}')

def main():
    die1:int = 10
    print("die1 in main() starts as: " + str(die1))
    roll_dice()
    roll_dice()
    roll_dice()
    print("die1 in main() is: " + str(die1))

if __name__ == "__main__":
    main()
# Out:
# die1 in main() starts as: 10
# Total of two dice: 11
# Total of two dice: 10
# Total of two dice: 10
# die1 in main() is: 10

# %%
print("2_e=mc2")

def main():
    C = 299792458  # speed of light in m/s
    mass_in_kg: float = float(input("Enter kilos of mass: "))

    energy_in_joules: float = mass_in_kg * (C ** 2)

    print("e = m * C^2...")
    print("m = " + str(mass_in_kg) + " kg")
    print("C = " + str(C) + " m/s")

    print(str(energy_in_joules) + " joules of energy!")

if __name__ == '__main__':
    main()
# Out:
# 2_e=mc2
# Enter kilos of mass: 130
# e = m * C^2...
# m = 130.0 kg
# C = 299792458 m/s
# 1.1683817323578628e+19 joules of energy!

# %%
print("3_feet_to_inches")

def main():
    INCHES_IN_FOOT = 12  # Define the constant
    feet: float = float(input("Enter number of feet: "))
    inches: float = feet * INCHES_IN_FOOT
    print("That is", inches, "inches!")

if __name__ == '__main__':
    main()
# Out:
# 3_feet_to_inches
# Enter number of feet: 1
# That is 12.0 inches!

# %%
import math  # Required for math.sqrt()

print("4_pythagorean_theorem")

def main():
    ab: float = float(input("Enter the length of AB: "))
    ac: float = float(input("Enter the length of AC: "))

    bc: float = math.sqrt(ab**2 + ac**2)
    print("The length of BC (the hypotenuse) is: " + str(bc))

if __name__ == '__main__':
    main()
# Out:
# 4_pythagorean_theorem
# Enter the length of AB: 1
# Enter the length of AC: 3
# The length of BC (the hypotenuse) is: 3.1622776601683795

# %%
print("5_remainder_division.")

def main():
    dividend: int = int(input("Please enter an integer to be divided: "))
    divisor: int = int(input("Please enter an integer to divide by: "))

    quotient: int = dividend // divisor
    remainder: int = dividend % divisor

    print("The result of this division is " + str(quotient) + " with a remainder of " + str(remainder))



if __name__ == '__main__':
    main()
# Out:
# 5_remainder_division.
# Please enter an integer to be divided: 1
# Please enter an integer to divide by: 2
# The result of this division is 0 with a remainder of 1

# %%
print("6_seconds_in_year.")

DAYS_PER_YEAR: int = 365
HOURS_PER_DAY: int = 24
MIN_PER_HOUR: int = 60
SEC_PER_MIN: int = 60

def main():
    try:
        years = int(input("Enter number of years: "))
        total_seconds = years * DAYS_PER_YEAR * HOURS_PER_DAY * MIN_PER_HOUR * SEC_PER_MIN
        print(f"There are {total_seconds:,} seconds in {years} year(s)!")
    except ValueError:
        print("Please enter a valid number of years.")

if __name__ == '__main__':
    main()

# %%
print("07_tiny_mad_li")

SENTENCE_START: str = "Panaversity is fun. I learned to program and used Python to make my " # adjective noun verb

def main():

    adjective: str = input("Please type an adjective and press enter. ")
    noun: str = input("Please type a noun and press enter. ")
    verb: str = input("Please type a verb and press enter. ")

    print(SENTENCE_START + adjective + " " + noun + " " + verb + "!")




if __name__ == '__main__':
    main()
# Out:
# 07_tiny_mad_li
# Please type an adjective and press enter. aaa
# Please type a noun and press enter. apple
# Please type a verb and press enter. eat
# Panaversity is fun. I learned to program and used Python to make my aaa apple eat!
